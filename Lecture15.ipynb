# %% [markdown]
# # Relation to non-intersecting lattice paths, lozenge tilings, domino tilings and five-vertex model

# %% [markdown]
# Not much to show here, but I share a file `azteclozenge.py` with two functions. First is `draw_skew_lozenge tiling` which draws lozenge tilings of glued hexagons. Second one is `draw_diamond_tiling`, it draws domino tilings of glued Aztec diamonds. Below is an example of its use.

# %%
from azteclozenge import draw_skew_lozenge_tiling, draw_diamond_tiling

# %%
# %runfile dual_rsk_sage.pyx
# Out:
# Compiling ./dual_rsk_sage.pyx...

# %%
import numpy as np
rng=np.random.default_rng()

n=3
k=4
a=1
b=1
xs=a*np.ones(n)
ys=b*np.ones(k)
ab=np.outer(xs,ys)
zeroonematrix=np.array(rng.uniform(size=ab.shape)>ab/(1+ab),dtype='int8')

P,Q=dual_rsk(zeroonematrix)

# %%
P, Q
# Out:
# ([[1, 1], [2, 2], [4, 4], []], [[1, 1, 2], [2, 3, 3], []])

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 10]
draw_skew_lozenge_tiling(P,Q,n,k)

# %%
draw_diamond_tiling(P,Q,n,k)

# %%
import numpy as np
rng=np.random.default_rng()

n=25
k=35
a=1
b=1
xs=a*np.ones(n)
ys=b*np.ones(k)
ab=np.outer(xs,ys)
zeroonematrix=np.array(rng.uniform(size=ab.shape)>ab/(1+ab),dtype='int8')

P,Q=dual_rsk(zeroonematrix)

# %%
draw_skew_lozenge_tiling(P,Q,n,k)

# %%
draw_diamond_tiling(P,Q,n,k)
